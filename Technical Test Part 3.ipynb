# %% [markdown]
# # Balancing Brackets
#
#
# ![Screen%20Shot%202018-09-20%20at%2009.37.05.png](attachment:Screen%20Shot%202018-09-20%20at%2009.37.05.png)
#
# Based on the above logic write function `

# %%
def parChecker(symbolString):
    return True

# %%
import unittest
test = unittest.TestCase()

# %%
# First test
test.assertEqual(1, 1)

# %%
# Second test

parentheses = '((()))'
expected_result = True

test.assertEqual(parChecker(parentheses),expected_result)

# %%
# Third test

parentheses = '((())'
expected_result = False

test.assertEqual(parChecker(parentheses),expected_result)

# %%
# Fourth test

parentheses = '{(())'
expected_result = False

test.assertEqual(parChecker(parentheses),expected_result)
